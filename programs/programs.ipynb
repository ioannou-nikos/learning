# %%
import pandas as pd
def is_int(s):
    try:
        int(s)
        print(s)
        return True
    except ValueError:
        return False

# %%
names = ("counter","ergo_id","kae_exodou","etos_entaksis","sn","titlos","eggekrimenos","proteinomenos","pliromes_2016","ipoloipo_2017","pist_2017","pist_2018","pist_2019","pist_2020","ipiresia","sxolia")
xls = pd.read_excel("anaptixiakos_trop_01_2017.xls", sheetname=1, skiprows=[0,1,2,3,4,5], names=names)
erga = xls[xls.ergo_id.isnull() == False]
erga = erga[erga.etos_entaksis != 'ΕΤΟΣ ΕΝΤΑΞΗΣ ']
work = erga[["ergo_id","etos_entaksis","eggekrimenos","proteinomenos","pliromes_2016","ipoloipo_2017","pist_2017","pist_2018","pist_2019","pist_2020"]]
work = work.apply(pd.to_numeric, errors='ignore')
work.groupby(by='etos_entaksis').sum()
# Out:
#                eggekrimenos  proteinomenos  pliromes_2016  ipoloipo_2017  \
# etos_entaksis
# 2012               36285.00       36285.00           0.00       36285.00
# 2013             1400071.63     1681848.31     1089891.48      591956.83
# 2014              102000.00      102000.00           0.00      102000.00
# 2015              761614.91      761614.91      127265.73      634349.18
# 2016              577000.00      577000.00      216000.00      361000.00
# 2017                   0.00      357000.00           0.00      357000.00
#
#                pist_2017  pist_2018  pist_2019  pist_2020
# etos_entaksis
# 2012            36285.00       0.00        0.0        0.0
# 2013           566956.83   25000.00        0.0        0.0
# 2014           102000.00       0.00        0.0        0.0
# 2015           340299.17  294050.01        0.0        0.0
# 2016           352000.00    9000.00        0.0        0.0
# 2017             2000.00  177000.00   178000.0        0.0

# %%
xls
# Out:
#     ΕΛΛΛΗΝΙΚΗ ΔΗΜΟΚΡΑΤΙΑ \nΠΕΡΙΦΕΡΕΙΑ ΚΕΝΤΡΙΚΗΣ ΜΑΚΕΔΟΝΙΑΣ\nΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΘΕΣΣΑΛΟΝΙΚΗΣ  \
# 0                                                  NaN
# 1    1η ΤΡΟΠΟΠΟΙΗΣΗ ΑΝΑΠΤΥΞΙΑΚΟΥ ΠΡΟΫΠΟΛΟΓΙΣΜΟΥ (ΠΡ...
# 2                                                  NaN
# 3                                                  Α/Α
# 4                                                  NaN
# 5    ΑΞΟΝΑΣ 1 - ΠΡΟΣΤΑΣΙΑ ΠΕΡΙΒΑΛΛΟΝΤΟΣ ΚΑΙ ΒΕΛΤΙΩΣ...
# 6    ΜΕΤΡΟ 1.2 ΠΡΟΣΤΑΣΙΑ ΚΑΙ ΑΝΑΔΕΙΞΗ ΦΥΣΙΚΟΥ ΚΑΙ Δ...
# 7    ΣΤΟΧΟΣ 1.2.2 ΠΡΟΣΤΑΣΙΑ, ΑΝΑΔΕΙΞΗ ΚΑΙ ΑΠΟΚΑΤΑΣΤ...
# 8       ΔΡΑΣΗ 1.2.2.2 Έργα αποκατάστασης περιβάλλοντος
# 9                                                    1
# 10                               ΣΥΝΟΛΟ ΔΡΑΣΗΣ 1.1.2.2
# 11                                                 NaN
# 12                                                 NaN
# 13     ΜΕΤΡΟ 1.5 ΔΙΑΧΕΙΡΙΣΗ ΥΔΑΤΙΝΩΝ ΠΟΡΩΝ - ΥΔΡΕΥΣΕΙΣ
# 14          ΣΤΟΧΟΣ 1.5.3 ΒΕΛΤΙΩΣΗ ΥΠΟΔΟΜΩΝ ΚΑΙ ΔΙΚΤΥΩΝ
# ...
